# %%
import pandas as pd

# %%
pd.read_csv("Cleaned_google_playstore_data.csv")
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv("Cleaned_google_playstore_data.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0       4.0.3
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver Android Ver  Day  \
# ...

# %%
df.sample(10)
# Out:
#                                              App           Category  Rating  \
# 4128               HumorCast - Authentic Weather            WEATHER     4.4
# 418   Dolphin Browser - Fast, Private & Adblock🐬      COMMUNICATION     4.5
# 4405                 Guns'n'Glory Heroes Premium             FAMILY     4.3
# 1030                                  Prosperity             EVENTS     5.0
# 82                           Supervision service  AUTO_AND_VEHICLES     4.0
# 6426                        OTOME of Ikemen cafe             FAMILY     4.5
# 2393                               Free Hypnosis            MEDICAL     4.2
# 7295                             CG Samanya Gyan             FAMILY     4.2
# 6278                        bi-Cube Mobile Token              TOOLS     NaN
# 4402              Read Unlimitedly! Kids'n Books             FAMILY     3.8
#
#       Reviews     Size  Installs  Type  Price Content Rating  \
# 4128     6495  40000.0    100000  Free   0.00           Teen
# ...

# %%
df.shape
# Out:
# (10840, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     9476 non-null   object
#  13  Day             10840 non-null  int64
#  14  Month           10840 non-null  int64
#  15  Year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# Day                 int64
# Month               int64
# Year                int64
# dtype: object

# %%
df.describe()
# Out:
#             Rating       Reviews           Size      Installs         Price  \
# count  9366.000000  1.084000e+04    9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05   21506.534062  1.546434e+07      1.027368
# std       0.515219  2.927761e+06   22596.020795  8.502936e+07     15.949703
# min       1.000000  0.000000e+00      10.000000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01    4900.000000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03   13000.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04   30000.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09    400.000000
#
#                 Day         Month          Year
# count  10840.000000  10840.000000  10840.000000
# mean      15.609041      6.422325   2017.399723
# std        9.561621      2.578388      1.100914
# min        1.000000      1.000000   2010.000000
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day', 'Month', 'Year'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10835    False
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# Length: 10840, dtype: bool

# %%
df[df.duplicated()]        # will show duplicated rows
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df[df.duplicated("App")]              # Will show duplicated Apps
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10714                  FarmersOnly Dating         DATING     3.0     1145
# 10719  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10729                         FP Notebook        MEDICAL     4.5      410
# 10752      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10767                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# ...

# %%
# We have 1181 duplicate apps name. This needs to be removed

# %%
df = df.drop_duplicates(subset = "App", keep = "first")    # will drop duplicate app amd keep the first occurance.

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (9659, 16)

# %%
numeric_feature = [feature for feature in df.columns if df[feature].dtypes != "O"]

# %%
numeric_feature
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Day', 'Month', 'Year']

# %%
categorical_feature = [feature for feature in df.columns if df[feature].dtypes == "O"]

# %%
categorical_feature
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df[categorical_feature]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[numeric_feature]
# Out:
#        Rating  Reviews     Size  Installs  Price  Day  Month  Year
# 0         4.1      159  19000.0     10000    0.0    7      1  2018
# 1         3.9      967  14000.0    500000    0.0   15      1  2018
# 2         4.7    87510   8700.0   5000000    0.0    1      8  2018
# 3         4.5   215644  25000.0  50000000    0.0    8      6  2018
# 4         4.3      967   2800.0    100000    0.0   20      6  2018
# ...       ...      ...      ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53000.0      5000    0.0   25      7  2017
# 10836     5.0        4   3600.0       100    0.0    6      7  2018
# 10837     NaN        3   9500.0      1000    0.0   20      1  2017
# 10838     4.5      114      NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19000.0  10000000    0.0   25      7  2018
#
# [9659 rows x 8 columns]

# %%
# for categorical data, we can use value_counts()

# %%
categorical_feature
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df["Category"].value_counts()
# Out:
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   56
# BEAUTY                   53
# ...

# %%
df["Type"].value_counts()
# Out:
# Free    8902
# Paid     756
# Name: Type, dtype: int64

# %%
df["Type"].value_counts(normalize = True)
# Out:
# Free    0.921723
# Paid    0.078277
# Name: Type, dtype: float64

# %%
# free is 92.17 % and Paid is 07.82 %

# %%
df["Genres"].value_counts()
# Out:
# Tools                              826
# Entertainment                      561
# Education                          510
# Business                           420
# Medical                            395
#                                   ...
# Art & Design;Pretend Play            1
# Lifestyle;Pretend Play               1
# Comics;Creativity                    1
# Art & Design;Action & Adventure      1
# Strategy;Creativity                  1
# Name: Genres, Length: 118, dtype: int64

# %%
# code for finding value counts for all columns in categorical data
for feature in categorical_feature:
    print(f"Column = {feature}")
    print(df[feature].value_counts())
    print("===========================================================")
# Out:
# Column = App
# Photo Editor & Candy Camera & Grid & ScrapBook    1
# Tic Tac CK                                        1
# INFAMY RO                                         1
# CK Call NEW                                       1
# Ck Coif                                           1
#                                                  ..
# Bike Race Free - Top Motorcycle Racing Games      1
# Dance School Stories - Dance Dreams Come True     1
# 3D Bowling                                        1
# Mind Games Pro                                    1
# iHoroscope - 2018 Daily Horoscope & Astrology     1
# Name: App, Length: 9659, dtype: int64
# ...
# Column = Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# ...

# %%
categorical_feature
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
sns.countplot(x = df["Type"])
# Out:
# <AxesSubplot: xlabel='Type', ylabel='count'>

# %%
sns.countplot(x = df["Content Rating"])
# Out:
# <AxesSubplot: xlabel='Content Rating', ylabel='count'>

# %%
sns.countplot(x = df["Category"])
# Out:
# <AxesSubplot: xlabel='Category', ylabel='count'>

# %%
# These are all uvivariate analysis

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold',
alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
# categorical columns
# plt.figure(figsize=(20, 15))
# plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold',
# alpha=0.8, y=1.)
# category = [ 'App', 'Genres']
# for i in range(0, len(category)):
#     plt.subplot(2, 2, i+1)
#     sns.countplot(x=df[category[i]],palette="Set2")
#     plt.xlabel(category[i])
#     plt.xticks(rotation=45)
#     plt.tight_layout()

# %%
# Numerical data

# %%
numeric_feature
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Day', 'Month', 'Year']

# %%
sns.kdeplot(df["Rating"])
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Density'>

# %%
sns.kdeplot(df["Price"])
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Density'>

# %%
sns.kdeplot(df["Reviews"])
# Out:
# <AxesSubplot: xlabel='Reviews', ylabel='Density'>

# %%
sns.kdeplot(df["Installs"])
# Out:
# <AxesSubplot: xlabel='Installs', ylabel='Density'>

# %%
# For Numric data, we plot kde plot
# For Categorical data, we plot count plot

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_feature)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[numeric_feature[i]],shade=True, color='r')
    plt.xlabel(numeric_feature[i])
    plt.tight_layout()

# %%
sns.distplot(df["Reviews"])
# Out:
# <AxesSubplot: xlabel='Reviews', ylabel='Density'>

# %%
sns.distplot(df["Rating"])
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df["Size"])
# Out:
# <AxesSubplot: xlabel='Size', ylabel='Density'>

# %%
plt.hist(df["Size"])
# Out:
# (array([3931., 1534., 1066.,  594.,  431.,  276.,  197.,  131.,  108.,
#          164.]),
#  array([1.0000e+01, 1.0009e+04, 2.0008e+04, 3.0007e+04, 4.0006e+04,
#         5.0005e+04, 6.0004e+04, 7.0003e+04, 8.0002e+04, 9.0001e+04,
#         1.0000e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["Rating"])
plt.show()

# %%
# Univariate Analysis :-

# %%
# Q. Most popular category in App?

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  Day  Month  \
# 0               Art & Design   2018-01-07       1.0.0       4.0.3    7      1
# 1  Art & Design;Pretend Play   2018-01-15       2.0.0       4.0.3   15      1
#
#    Year
# 0  2018
# 1  2018

# %%
df[["Category"]].value_counts()
# Out:
# Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   56
# ...

# %%
df[df["Category"] == "FAMILY"]
# Out:
#                                                      App Category  Rating  \
# 2017                        Jewels Crush- Match 3 Puzzle   FAMILY     4.4
# 2018                                    Coloring & Learn   FAMILY     4.4
# 2019                                             Mahjong   FAMILY     4.5
# 2020   Super ABC! Learning games for kids! Preschool ...   FAMILY     4.6
# 2021                                       Toy Pop Cubes   FAMILY     4.5
# ...                                                  ...      ...     ...
# 10820                                            Poop FR   FAMILY     NaN
# 10826                                 Fr Agnel Ambarnath   FAMILY     4.2
# 10833                                      FR Calculator   FAMILY     4.0
# 10835                                   Sya9a Maroc - FR   FAMILY     4.5
# 10836                   Fr. Mike Schmitz Audio Teachings   FAMILY     5.0
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...
